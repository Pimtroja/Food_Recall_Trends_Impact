# %% [markdown]
# **Data Cleaning _ Combined (1+2)**

# %% [markdown]
# **Class I** is a situation in which there is a reasonable probability that the use of, or exposure to, a violative product will cause serious adverse health consequences or death.
# **Class II** is a situation in which use of, or exposure to, a violative product may cause temporary or medically reversible adverse health consequences or where the probability of serious adverse health consequences is remote.
# **Class III** is a situation in which use of, or exposure to, a violative product is not likely to cause adverse health consequences.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

fda_path = r"C:\Users\Ahjung\Downloads\Food_Recall.csv"
fda = pd.read_csv(fda_path)
fda
# Out:
#        FEI Number                 Recalling Firm Name    Product Type  \
# 0      3004312676                   HAR Maspeth Corp.  Food/Cosmetics
# 1         2938745                    Lyons Magnus LLC  Food/Cosmetics
# 2         2938745                    Lyons Magnus LLC  Food/Cosmetics
# 3         2938745                    Lyons Magnus LLC  Food/Cosmetics
# 4         2938745                    Lyons Magnus LLC  Food/Cosmetics
# ...           ...                                 ...             ...
# 27521  3004404050                    Panera Bread LLC  Food/Cosmetics
# 27522  3004162088      DSM Nutritional Products, Inc.  Food/Cosmetics
# 27523  3002727068                     Best West Foods  Food/Cosmetics
# 27524  3002727068                     Best West Foods  Food/Cosmetics
# 27525  3005339147  Diversified Natural Products, Inc.  Food/Cosmetics
#
#       Product Classification      Status  \
# 0                    Class I     Ongoing
# 1                    Class I     Ongoing
# 2                    Class I     Ongoing
# 3                    Class I     Ongoing
# 4                    Class I     Ongoing
# ...                      ...         ...
# 27521               Class II  Terminated
# 27522               Class II  Terminated
# 27523               Class II  Terminated
# 27524               Class II  Terminated
# 27525               Class II  Terminated
#
#                                     Distribution Pattern Recalling Firm City  \
# 0                 NY, NJ, MA, CT, PA, MD, NC, IL, MI, GA             Maspeth
# 1      Distribution centers located throughout the U....              Fresno
# 2      Distribution centers located throughout the U....              Fresno
# 3      Distribution centers located throughout the U....              Fresno
# 4      Distribution centers located throughout the U....              Fresno
# ...                                                  ...                 ...
# 27521                                         Nationwide         Saint Louis
# 27522                                         NJ, WI, IL          Parsippany
# 27523                                           NV only.           Las Vegas
# 27524                                           NV only.           Las Vegas
# 27525  WA,MI,NC,MN,FL,NH,AR,PA,MA,GA,TX,IN, \r\nWinni...          Scottville
#
#       Recalling Firm State Recalling Firm Country Center Classification Date  \
# 0                 New York          United States                 03/21/2025
# 1               California          United States                 03/20/2025
# 2               California          United States                 03/20/2025
# 3               California          United States                 03/20/2025
# 4               California          United States                 03/20/2025
# ...                    ...                    ...                        ...
# 27521             Missouri          United States                 06/08/2012
# 27522           New Jersey          United States                 06/08/2012
# 27523               Nevada          United States                 06/08/2012
# 27524               Nevada          United States                 06/08/2012
# 27525             Michigan          United States                 06/08/2012
#
#                                        Reason for Recall  \
# 0                                Contains undeclared egg
# 1      Potential contamination with Listeria monocyto...
# 2      Potential contamination with Listeria monocyto...
# 3      Potential contamination with Listeria monocyto...
# 4      Potential contamination with Listeria monocyto...
# ...                                                  ...
# 27521  Product ingredient statement reversed for  Red...
# 27522             Flavor is contaminated with Salmonella
# 27523  Soy was not included in the ingredient stateme...
# 27524  Soy was not included in the ingredient stateme...
# 27525        undeclared milk present in butter flavoring
#
#                                      Product Description  Event ID  \
# 0      Jinga Glass Noodles with vegetables 8 oz. and ...     96503
# 1      Ready Care Chocolate Shake (4 oz), UPC 1004579...     96376
# 2      Ready Care Strawberry Shake (4 oz), UPC 100457...     96376
# 3      Ready Care Vanilla Shake (4 oz), UPC 100457960...     96376
# 4      Ready Care Chocolate Shake No Sugar Added (4 o...     96376
# ...                                                  ...       ...
# 27521  Panera ,HAZELNUT CREAM CHEESE SPREAD Reduced F...     61831
# 27522  GB Select Roast Meat Type Flavor Net Wt. 55 lb...     61936
# 27523  Florentine Lasagna Rolls;\r\nPerishable, keep ...     61968
# 27524  Cheese Lasagna Rolls;\r\nPerishable, keep froz...     61968
# 27525  AlsoSalt Sodium Free Butter flavored Salt Subs...     61924
#
#       Event Classification  Product ID Center  \
# 0                  Class I      213039  CFSAN
# 1                  Class I      212741  CFSAN
# 2                  Class I      212977  CFSAN
# 3                  Class I      212978  CFSAN
# 4                  Class I      212982  CFSAN
# ...                    ...         ...    ...
# 27521             Class II      109200  CFSAN
# 27522             Class II      109523  CFSAN
# 27523             Class II      109609  CFSAN
# 27524             Class II      109610  CFSAN
# 27525             Class II      109494  CFSAN
#
#                                           Recall Details
# 0      https://www.accessdata.fda.gov/scripts/ires/?P...
# 1      https://www.accessdata.fda.gov/scripts/ires/?P...
# 2      https://www.accessdata.fda.gov/scripts/ires/?P...
# 3      https://www.accessdata.fda.gov/scripts/ires/?P...
# 4      https://www.accessdata.fda.gov/scripts/ires/?P...
# ...                                                  ...
# 27521  https://www.accessdata.fda.gov/scripts/ires/?P...
# 27522  https://www.accessdata.fda.gov/scripts/ires/?P...
# 27523  https://www.accessdata.fda.gov/scripts/ires/?P...
# 27524  https://www.accessdata.fda.gov/scripts/ires/?P...
# 27525  https://www.accessdata.fda.gov/scripts/ires/?P...
#
# [27526 rows x 17 columns]

# %%
#filtering out "cosmetic" products
fda_1 = fda[~fda["Product Description"].str.contains("cosmetic|shampoo", case=False, na=False)]
fda_1 = fda[~fda["Reason for Recall"].str.contains("cosmetic|shampoo", case=False, na=False)]

# %%
#Removing duplicated rows
fda_1 = fda_1.drop_duplicates(subset="FEI Number")

# %%
#"nationwide"
fda_1["Nationwide"]=np.nan
nationwide = r"(nationwide|throughout the U\.S\.|thru out the United States\.)"
fda_1.loc[fda_1["Distribution Pattern"].str.contains(nationwide, case=False, na=False), "Nationwide"] = "Yes"
fda_1.loc[fda_1["Nationwide"].isnull(), "Nationwide"] = "No"
# Out:
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2520524830.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   fda_1.loc[fda_1["Distribution Pattern"].str.contains(nationwide, case=False, na=False), "Nationwide"] = "Yes"
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2520524830.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Yes' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fda_1.loc[fda_1["Distribution Pattern"].str.contains(nationwide, case=False, na=False), "Nationwide"] = "Yes"

# %%
#undeclared ingredient
ecoli = r"(E. coli|E Coli)"
fda_1.loc[fda_1["Reason for Recall"].str.contains(ecoli, case=False, na=False), "Reason for Recall"] = "E.coli"

#Listeria
listeria = r"(listeria|L. mono|monocytogenes)"
fda_1.loc[fda_1["Reason for Recall"].str.contains(listeria, case=False, na=False), "Reason for Recall"] = "Listeria"

#Salmonella
salmonella = r"(salmonella|Salmonellosis)"
fda_1.loc[fda_1["Reason for Recall"].str.contains(salmonella, case=False, na=False), "Reason for Recall"] = "Salmonella"

#Pseudomonas
pseudomonas = r"(Pseudomonas)"
fda_1.loc[fda_1["Reason for Recall"].str.contains(pseudomonas, case=False, na=False), "Reason for Recall"] = "Pseudomonas"
# Out:
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2159548964.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   fda_1.loc[fda_1["Reason for Recall"].str.contains(ecoli, case=False, na=False), "Reason for Recall"] = "E.coli"
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2159548964.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   fda_1.loc[fda_1["Reason for Recall"].str.contains(listeria, case=False, na=False), "Reason for Recall"] = "Listeria"
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2159548964.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   fda_1.loc[fda_1["Reason for Recall"].str.contains(salmonella, case=False, na=False), "Reason for Recall"] = "Salmonella"
# C:\Users\Ahjung\AppData\Local\Temp\ipykernel_21956\2159548964.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   fda_1.loc[fda_1["Reason for Recall"].str.contains(pseudomonas, case=False, na=False), "Reason for Recall"] = "Pseudomonas"

# %%
#Date to Month and Year
fda_1["Center Classification Date"] = pd.to_datetime(fda_1["Center Classification Date"])
fda_1["Year"] = fda_1["Center Classification Date"].dt.year
fda_1["Month"] = fda_1["Center Classification Date"].dt.month

# %%
fda_1.reset_index(drop=True, inplace=True)

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install us
# %load_ext sql
db_path = "Food_Recall.db"
import sqlite3
import pandas as pd
import numpy as np
import re #import regular expressions module (set of string that matches the criteria)
from collections import defaultdict
import us #import us library

conn = fda_1
conn = sqlite3.connect("Food_Recall.db")
fda.to_sql("Food_Recall", conn, if_exists="replace", index=False)
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ahjung\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (2.0.34)
# Requirement already satisfied: sqlparse in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (0.5.2)
# Requirement already satisfied: six in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\ahjung\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ahjung\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ahjung\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ahjung\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ahjung\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ahjung\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\ahjung\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ahjung\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ahjung\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\ahjung\anaconda3\lib\site-packages (2.0.34)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ahjung\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ahjung\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: us in c:\users\ahjung\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: jellyfish in c:\users\ahjung\anaconda3\lib\site-packages (from us) (1.0.1)
# 27526

# %%
#checking for missing values
fda_1.isnull().sum()
# Out:
# FEI Number                    0
# Recalling Firm Name           0
# Product Type                  0
# Product Classification        0
# Status                        0
# Distribution Pattern          0
# Recalling Firm City           0
# Recalling Firm State          0
# Recalling Firm Country        0
# Center Classification Date    0
# Reason for Recall             0
# Product Description           0
# Event ID                      0
# Event Classification          0
# Product ID                    0
# Center                        0
# Recall Details                0
# Nationwide                    0
# Year                          0
# Month                         0
# dtype: int64

# %%
#drop unrelated columns
fda_1 = fda_1.drop(columns = ["Event ID", "Center", "Recall Details"])

# %%
#Count each state once per row even if both abbreviation and full name appear
#Count either abbreviation or full name, not both, only one per state per row
#Sum that up across all rows for each state

#create dictionary of state abbreviations and full names
states = {state.abbr: state.name for state in us.states.STATES}

#Store in count number
state_counts = defaultdict(int)

#Loop through each row in the fda_1 DataFrame
for i, row in fda_1.dropna(subset=['Distribution Pattern']).iterrows():
    pattern = row["Distribution Pattern"].lower()

    #If "Nationewide" column is "Yes", add 1 to all states
    if str(row.get("Nationwide", "")).strip().lower() == "Yes":
        for full in states.values():
            state_counts[full] += 1
            
#If "Naionwide" is not "Yes", check each state abbreviation and full name
    else:
        for abbr, full in states.items():
            if (re.search(r'\b' + abbr + r'\b', pattern, flags = re.IGNORECASE) or
             re.search(r'\b' + full + r'\b', pattern, flags = re.IGNORECASE)):
             state_counts[full] += 1

#Get a count of how many rows mention each state
#Convert to DataFrame
state_counts = pd.DataFrame([
    {'State': full, 'Count': count} for full, count in state_counts.items()
])

state_counts
# Out:
#              State  Count
# 0      Connecticut    525
# 1          Georgia    750
# 2         Illinois    989
# 3         Maryland    619
# 4    Massachusetts    636
# 5         Michigan    698
# 6       New Jersey    798
# 7         New York   1132
# 8   North Carolina    661
# 9     Pennsylvania    972
# 10         Indiana   1713
# 11           Idaho    260
# 12      Washington    794
# 13         Arizona    555
# 14      California   1292
# 15         Florida    950
# 16          Nevada    391
# 17          Oregon    662
# 18           Texas   1022
# 19        Delaware    220
# 20            Ohio    793
# 21          Alaska    118
# 22        Kentucky    454
# 23       Minnesota    553
# 24     Mississippi    262
# 25        Missouri    539
# 26       Tennessee    514
# 27        Virginia    765
# 28   West Virginia    185
# 29       Wisconsin    629
# 30         Alabama    404
# 31        Arkansas    305
# 32        Colorado    588
# 33       Louisiana    352
# 34        Nebraska    281
# 35   New Hampshire    318
# 36      New Mexico    235
# 37        Oklahoma    348
# 38    Rhode Island    213
# 39  South Carolina    445
# 40            Iowa    440
# 41          Kansas    386
# 42           Maine    256
# 43         Wyoming    149
# 44         Montana    184
# 45          Hawaii    168
# 46    South Dakota    164
# 47            Utah    384
# 48         Vermont    167
# 49    North Dakota    160

# %%
#fda_1.to_csv(r'C:\Users\Ahjung\Downloads\cleaned_data.csv', index=True)
