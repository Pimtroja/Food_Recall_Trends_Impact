# %% [markdown]
# <h5>US Census Population 2020 to 2025 Extraction</h5>
# <h6></h6>

# %%
import pandas as pd
import numpy as np
import re #import regular expressions module (set of string that matches the criteria)
from collections import defaultdict
import us #import us library
pop_census1 = pd.read_csv("Pop_2010to2019.csv")
pop_census2 = pd.read_csv("USCensus_2020_2024.csv")

# %%
#inspecting data using Python
#display data first 5 rows
pop_census1.head()
pop_census2.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0      10      0        0      0     United States          331515736
# 1      20      1        0      0  Northeast Region           57617706
# 2      30      1        1      0       New England           15122011
# 3      30      1        2      0   Middle Atlantic           42495695
# 4      20      2        0      0    Midwest Region           68998970
#
#    POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  POPESTIMATE2023  ...  \
# 0        331577720        332099760        334017321        336806231  ...
# 1         57431458         57252533         57159597         57398303  ...
# 2         15057350         15118145         15175633         15263573  ...
# 3         42374108         42134388         41983964         42134730  ...
# 4         68984258         68872831         68903297         69186401  ...
#
#    NRANK_NPCHG2020  NRANK_NPCHG2021  NRANK_NPCHG2022  NRANK_NPCHG2023  \
# ...

# %%
#checking for missing values
#pop_census1.isnull().sum()
#pop_census2.isnull().sum()
#no null

# %%
#view all columns
print(pop_census1.columns.tolist())
print(pop_census2.columns.tolist())
# Out:
# ['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019', 'NPOPCHG_2010', 'NPOPCHG_2011', 'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015', 'NPOPCHG_2016', 'NPOPCHG_2017', 'NPOPCHG_2018', 'NPOPCHG_2019', 'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014', 'BIRTHS2015', 'BIRTHS2016', 'BIRTHS2017', 'BIRTHS2018', 'BIRTHS2019', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013', 'DEATHS2014', 'DEATHS2015', 'DEATHS2016', 'DEATHS2017', 'DEATHS2018', 'DEATHS2019', 'NATURALINC2010', 'NATURALINC2011', 'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015', 'NATURALINC2016', 'NATURALINC2017', 'NATURALINC2018', 'NATURALINC2019', 'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012', 'INTERNATIONALMIG2013', 'INT
# ...

# %%
#drop columns
pop_census2_1 = pop_census2.drop(columns=pop_census2.loc[:, 'SUMLEV':'STATE'].columns)
pop_census2_1 = pop_census2_1.drop(columns=pop_census2_1.loc[:, 'NPOPCHG_2020':'NRANK_PPCHG2024'].columns)
pop_census2_1 = pop_census2_1.drop(columns='ESTIMATESBASE2020')
pop_census2_1.head()
# Out:
#                NAME  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# 0     United States        331577720        332099760        334017321
# 1  Northeast Region         57431458         57252533         57159597
# 2       New England         15057350         15118145         15175633
# 3   Middle Atlantic         42374108         42134388         41983964
# 4    Midwest Region         68984258         68872831         68903297
#
#    POPESTIMATE2023  POPESTIMATE2024
# 0        336806231        340110988
# 1         57398303         57832935
# 2         15263573         15386085
# 3         42134730         42446850
# 4         69186401         69596584

# %%
#drop columns for pop_census1
pop_census1_1 = pop_census1.drop(columns=pop_census1.loc[:, 'SUMLEV':'STATE'].columns)
pop_census1_1 = pop_census1_1.drop(columns=pop_census1_1.loc[:, 'NPOPCHG_2010':'RNETMIG2019'].columns)
pop_census1_1 = pop_census1_1.drop(columns=pop_census1_1.loc[:, 'CENSUS2010POP':'POPESTIMATE2011'].columns)
pop_census1_1.head()
# Out:
#                NAME  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0     United States        313830990        315993715        318301008
# 1  Northeast Region         55775216         55901806         56006011
# 2    Midwest Region         67336743         67560379         67745167
# 3      South Region        117241208        118364400        119624037
# 4       West Region         73477823         74167130         74925793
#
#    POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0        320635163        322941311        324985539        326687501
# 1         56034684         56042330         56059240         56046620
# 2         67860583         67987540         68126781         68236628
# 3        120997341        122351760        123542189        124569433
# 4         75742555         76559681         77257329         77834820
#
#    POPESTIMATE2019
# 0        328239523
# 1         55982803
# 2         68329004
# 3        125580448
# ...

# %%
#drop first 5 rows
#pop_census1_2 = pop_census1_1.iloc[5:]
pop_census1_2.shape

#pop_census2_2 = pop_census2_1.iloc[14:]
pop_census2_2.shape
# Out:
# (52, 6)

# %%
#remove DC and PR
#pop_census1_3 = pop_census1_2[~pop_census1_2['NAME'].isin(['District of Columbia','Puerto Rico'])]
#pop_census1_3.shape

#pop_census2_3 = pop_census2_2[~pop_census2_2['NAME'].isin(['District of Columbia','Puerto Rico'])]
pop_census2_3.shape
# Out:
# (50, 6)

# %%
#merge both dataset together
merged_census = pd.merge(pop_census1_3, pop_census2_3, on='NAME', how='inner')

# %%
merged_census.head()
# Out:
#          NAME  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0     Alabama          4815588          4830081          4841799
# 1      Alaska           730443           737068           736283
# 2     Arizona          6554978          6632764          6730413
# 3    Arkansas          2952164          2959400          2967392
# 4  California         37948800         38260787         38596972
#
#    POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0          4852347          4863525          4874486          4887681
# 1           737498           741456           739700           735139
# 2          6829676          6941072          7044008          7158024
# 3          2978048          2989918          3001345          3009733
# 4         38918045         39167117         39358497         39461588
#
#    POPESTIMATE2019  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# 0          4903185          5033094          5049196          5076181
# ...

# %%
merged_census.to_csv('Clean_USCensus_2012to2024.csv', index=False)
